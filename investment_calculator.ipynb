# %%
# from redfin import *
# from ipynb.fs.full.apartments import *

# %run apartments.ipynb  
# %run redfin.ipynb

# %%
allzips = get_all_city(county=None, major_city=None)
a_df = allzips[(allzips['population']>=10000) & (allzips['population_density']>=500)]
a_df = allzips[(allzips['state']=='NC')]
a_df.head()
# Out:
# TX    23
# CA    23
# FL    12
# AZ    10
# NV     7
# NC     6
# CO     6
# TN     5
# WA     5
# VA     4
# OR     3
# Name: usps, dtype: int64
# Number of city:6330
#       zipcode zipcode_type     major_city   post_office_city common_city_list  \
# 11279   27012     STANDARD       Clemmons       Clemmons, NC       [Clemmons]
# 11314   27101     STANDARD  Winston Salem  Winston Salem, NC  [Winston Salem]
# 11316   27103     STANDARD  Winston Salem  Winston Salem, NC  [Winston Salem]
# 11317   27104     STANDARD  Winston Salem  Winston Salem, NC  [Winston Salem]
# 11318   27105     STANDARD  Winston Salem  Winston Salem, NC  [Winston Salem]
#
#                county state    lat    lng          timezone radius_in_miles  \
# 11279  Forsyth County    NC  36.02 -80.38  America/New_York             7.0
# 11314  Forsyth County    NC   36.1 -80.24  America/New_York             4.0
# 11316  Forsyth County    NC  36.06 -80.32  America/New_York             5.0
# ...

# %%
df = a_df
c_df = []
for i in df['zipcode'].to_list():
    c_df.append(redfin_wrapper(i))

d_df = pd.concat(c_df)
# Out:
# zipcode:27012
# Num of pages:[]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       2 c_df = []
#       3 for i in df['zipcode'].to_list():
# ----> 4     c_df.append(redfin_wrapper(i))
#       6 d_df = pd.concat(c_df)
#
# File /var/folders/_0/ydhyzkgs55q43h1lb_2n0x640000gn/T/ipykernel_73493/4063369897.py:167, in redfin_wrapper(zipcode)
#     166 def redfin_wrapper(zipcode):
# --> 167     df = redfin_base_info(zipcode)
#     168     output_df = []
#     169     for i in df['address'].to_list():
#
# File /var/folders/_0/ydhyzkgs55q43h1lb_2n0x640000gn/T/ipykernel_73493/4063369897.py:44, in redfin_base_info(zipcode)
#      41 time.sleep(3)
#      42 base_list = []
# ---> 44 for i in range(1,int(num_page[0])+1):
#      45     page_url = url + '/page-' + str(i)
#      46     print(page_url)
#
# IndexError: list index out of range

# %%
e_df = d_df[d_df['monthly_cost'] <= d_df['predictedValueHigh']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 e_df = d_df[d_df['monthly_cost'] <= d_df['predictedValueHigh']]
#
# NameError: name 'd_df' is not defined

# %%
url = 'https://www.redfin.com/zipcode/{}'.format(str('27103'))
response = requests.get(url, headers=request_headers).text
soup = BeautifulSoup(response, 'html.parser')

# %%
soup
# Out:
#  <!DOCTYPE html5>
#
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <style type="text/css">
#
#     #submit {
#         -webkit-border-radius: 4;
#         -moz-border-radius: 4;
#         border-radius: 4px;
#         font-family: Arial;
#         font-size: 16px;
#         background: #0c82a5;
#         padding: 7px 10px 7px 10px;
#         text-decoration: none;
#         color: #ffffff;
#         border: none;
#     }
#
#     #submit:hover {
#         background: #3cb0fd;
#         text-decoration: none;
#     }
#
#     body {
#         font-family: Arial,"Helvetica Neue",Helvetica,sans-serif;
#         margin: 0;
#     }
#     div#header {
#         height: 59px;
#         width: 100%;
#         background-color: #fff;
# ...

# %%
# !pip3 install yellowtail
# Out:
# ERROR: Could not find a version that satisfies the requirement yellowtail (from versions: none)
# ERROR: No matching distribution found for yellowtail
